# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from PIL import Image
import PIL

# %%
#resize images
import os
from PIL import Image
p1="C:\\Users\\nayaz\\Desktop\\New folder\\ls\\bt\\images\\yes"
p3="C:\\Users\\nayaz\\Desktop\\New folder\\ls\\bt\\images\\no"
p2="C:\\Users\\nayaz\\Desktop\\New folder\\ls\\bt\\resize_images"
for f in os.listdir(p1):
    im=Image.open(p1+"\\"+f)
    img=im.resize((299,299))
    gray=img.convert("L")
    gray.save(p2+"\\yes\\"+f,"JPEG")

for f in os.listdir(p3):
    im=Image.open(p3+"\\"+f)
    img=im.resize((299,299))
    gray=img.convert("L")
    gray.save(p2+"\\no\\"+f,"JPEG")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7ca8b9231a8b> in <module>
#       5 p3="C:\\Users\\nayaz\\Desktop\\New folder\\ls\\bt\\images\\no"
#       6 p2="C:\\Users\\nayaz\\Desktop\\New folder\\ls\\bt\\resize_images"
# ----> 7 for f in os.listdir(p1):
#       8     im=Image.open(p1+"\\"+f)
#       9     img=im.resize((299,299))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\nayaz\\Desktop\\New folder\\ls\\bt\\images\\yes'

# %%
p1 = "C:\\Users\\nayaz\\Desktop\\braintumor\\augmented_dataset\\yes"

p3 = "C:\\Users\\nayaz\\Desktop\\braintumor\\augmented_dataset\\no"
p2 = "C:\\Users\\nayaz\\Desktop\\braintumor\\final_dataset"

for f in os.listdir(p1):
    #print(p1+"\\"+f)
    img=cv2.imread(p1+"\\"+f)
    #con_img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
#plt.subplot(121)
    plt.imshow(img)
    dst=cv2.fastNlMeansDenoising(img,h=2)
    img=Image.fromarray(dst)
    gray=img.convert('L')
    
    #plt.imshow(gray)
    gray.save(p2+"\\yes\\"+f)
    #print(type(img1))
    
    #img.save(p2+"\\yes\\"+img1,"JPEG")
    #img
    #cv2.imwrite(p2+"//yes",dst)
    #im = Image.fromarray(dst)
   # dst.save(p2+"\\yes\\"+f,"JPEG")
    #plt.subplot(121),plt.imshow(img)
    #d=plt.subplot(122),plt.imshow(dst)
    #d.save(p2+"\\no\\")
    #plt.show()

# %%
for f in os.listdir(p3):
    #print(p1+"\\"+f)
    img=cv2.imread(p3+"\\"+f)
    #con_img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
#plt.subplot(121)
#plt.imshow(img)
    dst=cv2.fastNlMeansDenoising(img,h=2)
    img=Image.fromarray(dst)
    gray=img.convert('L')
    gray.save(p2+"\\no\\"+f)
    #print(type(img1))
    
    #img.save(p2+"\\yes\\"+img1,"JPEG")
    #img
    #cv2.imwrite(p2+"//yes",dst)
    #im = Image.fromarray(dst)
   # dst.save(p2+"\\yes\\"+f,"JPEG")
    #plt.subplot(121),plt.imshow(img)
    #d=plt.subplot(122),plt.imshow(dst)
    #d.save(p2+"\\no\\")
    #plt.show()
