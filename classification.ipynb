# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
df =pd.DataFrame(data.data)
df.columns=data.feature_names
x_data = df
df1 = pd.DataFrame(data.target)
df1.columns=['Result']
y_data = df1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_data,y_data,test_size=0.1)

# %%
import matplotlib.pyplot as plt
n=len(x_train.columns)
for i in range(3):
  plt.scatter(x_train.iloc[:20,i],y_train.iloc[:20,0],label='attribute '+str(i))
plt.legend()
plt.show()

# %%
x_train
# Out:
#      mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 110        9.777         16.99  ...          0.2533                  0.08468
# 333       11.250         14.78  ...          0.2815                  0.07418
# 508       16.300         15.70  ...          0.2300                  0.07230
# 300       19.530         18.90  ...          0.2968                  0.09929
# 568        7.760         24.54  ...          0.2871                  0.07039
# 283       16.240         18.77  ...          0.2770                  0.10630
# 195       12.910         16.33  ...          0.3024                  0.06949
# 279       13.850         15.18  ...          0.2955                  0.06912
# 303       10.490         18.61  ...          0.2213                  0.07842
# 179       12.810         13.06  ...          0.1783                  0.07319
# 269       10.710         20.39  ...          0.2605                  0.08701
# 532       13.680         16.33  ...          0.2806                  0.07782
# 322       12.860         13.32  ...          0.2382                  0.08553
# 381       11.040         14.93  ...          0.3202                  0.07287
# 464       13.170         18.22  ...          0.2235                  0.06925
# 91        15.370         22.76  ...          0.2556                  0.06828
# 189       12.300         15.90  ...          0.2482                  0.06306
# 162       19.590         18.15  ...          0.3643                  0.09223
# 250       20.940         23.56  ...          0.3126                  0.07849
# 2         19.690         21.25  ...          0.3613                  0.08758
# 190       14.220         23.12  ...          0.5166                  0.14460
# 216       11.890         18.35  ...          0.3397                  0.08365
# 285       12.580         18.40  ...          0.2505                  0.06431
# 385       14.600         23.29  ...          0.2477                  0.06836
# 491       17.850         13.23  ...          0.1783                  0.05871
# 180       27.220         21.87  ...          0.2856                  0.08082
# 54        15.100         22.02  ...          0.2675                  0.07873
# 289       11.370         18.89  ...          0.3267                  0.06994
# 151        8.219         20.70  ...          0.3322                  0.14860
# 392       15.490         19.97  ...          0.3187                  0.10190
# ..           ...           ...  ...             ...                      ...
# 477       13.900         16.62  ...          0.2679                  0.07698
# 416        9.405         21.70  ...          0.2872                  0.08304
# 466       13.140         20.74  ...          0.2563                  0.08174
# 305       11.600         24.49  ...          0.3244                  0.06745
# 115       11.930         21.53  ...          0.2438                  0.08541
# 88        12.360         21.80  ...          0.2972                  0.09261
# 557        9.423         27.88  ...          0.2475                  0.06969
# 172       15.460         11.89  ...          0.3216                  0.10100
# 334       12.300         19.02  ...          0.2554                  0.07207
# 139       11.280         13.39  ...          0.2102                  0.06784
# 104       10.490         19.29  ...          0.2826                  0.07552
# 292       12.950         16.02  ...          0.3380                  0.09584
# 103        9.876         19.40  ...          0.2622                  0.08490
# 259       15.530         33.56  ...          0.3512                  0.12040
# 528       13.940         13.17  ...          0.2160                  0.07253
# 335       17.060         21.00  ...          0.2623                  0.07599
# 482       13.470         14.06  ...          0.3227                  0.09326
# 176        9.904         18.06  ...          0.2614                  0.11620
# 487       19.440         18.82  ...          0.3266                  0.09009
# 467        9.668         18.10  ...          0.3057                  0.07875
# 11        15.780         17.89  ...          0.3792                  0.10480
# 20        13.080         15.71  ...          0.3184                  0.08183
# 95        20.260         23.03  ...          0.3689                  0.08368
# 313       11.540         10.72  ...          0.3390                  0.07434
# 349       11.950         14.96  ...          0.3124                  0.07590
# 561       11.200         29.37  ...          0.1566                  0.05905
# 409       12.270         17.92  ...          0.3455                  0.06896
# 411       11.040         16.83  ...          0.2998                  0.07881
# 211       11.840         18.94  ...          0.2535                  0.07993
# 443       10.570         18.32  ...          0.2699                  0.06736
#
# [512 rows x 30 columns]
